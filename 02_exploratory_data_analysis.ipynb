# %%
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv("../dataset/cleaned_transactions.csv")
sns.countplot( data=df , x="Category" , order=df['Category'].value_counts().head(5).index )
plt.title("Top 5 Categories")
plt.show()
sns.countplot( data=df , x='Income/Expense' )
plt.title("Income vs Expense")
plt.show()
sns.histplot( df['Amount'], bins=30)
plt.title("Amount Distribution")
plt.show()
print(df.columns)
# Out:
# Index(['Date', 'Mode', 'Category', 'Subcategory', 'Note', 'Amount',
#        'Income/Expense', 'Currency'],
#       dtype='object')
